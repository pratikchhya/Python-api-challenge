# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Performing API calls

# base_url = "http://api.openweathermap.org/data/2.5/weather?"
base_url= "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

count = 1
sets = 1


weather_df = pd.DataFrame({"City": cities})
weather_df["Cloudiness"] = ""
weather_df["Country"] = ""
weather_df["Date"] = ""
weather_df["Humidity"] = ""
weather_df["Lat"] = ""
weather_df["Lon"] = ""
weather_df["Max Temp"] = ""
weather_df["Wind Speed"] = ""



print("Beginning Data Retrieval")
print("-----------------------------")
for index, row in weather_df.iterrows():
    city =row["City"]
    query_url = base_url + "&q=" +city
    response=requests.get(query_url).json()
    try:
        print(f"Processing Record {count}  of Set {sets} | {city}.")
        weather_df.loc[index,"Cloudiness"] = response["clouds"]["all"]
        weather_df.loc[index,"Country"] = response["sys"]["country"]
        weather_df.loc[index,"Date"] = response["dt"]
        weather_df.loc[index, "Humidity"] = response["main"]["humidity"]
        weather_df.loc[index, "Lat"] = response["coord"]["lat"]
        weather_df.loc[index, "Lon"] = response["coord"]["lon"]
        weather_df.loc[index, "Max Temp"] = response["main"]["temp_max"]
        weather_df.loc[index, "Wind Speed"] = response["wind"]["speed"]
    except:
        print("City not found...skipping.")
        
        weather_df.loc[index, "Cloudiness"]=""
        weather_df.loc[index, "Country"]=""
        weather_df.loc[index,"Date"]=""
        weather_df.loc[index, "Humidity"]=""
        weather_df.loc[index, "Lat"]=""
        weather_df.loc[index, "Lon"] = ""
        weather_df.loc[index, "Max Temp"]=""
        weather_df.loc[index, "Wind Speed"]=""
    if count == 50:
     count = 0
     sets = sets + 1

     
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1  of Set 1 | nikolskoye.
# Processing Record 1  of Set 1 | havoysund.
# Processing Record 1  of Set 1 | port hardy.
# Processing Record 1  of Set 1 | vaini.
# Processing Record 1  of Set 1 | tuktoyaktuk.
# Processing Record 1  of Set 1 | ponta do sol.
# Processing Record 1  of Set 1 | saskylakh.
# Processing Record 1  of Set 1 | busselton.
# Processing Record 1  of Set 1 | mataura.
# Processing Record 1  of Set 1 | bengkulu.
# City not found...skipping.
# Processing Record 1  of Set 1 | karauzyak.
# City not found...skipping.
# Processing Record 1  of Set 1 | russell.
# Processing Record 1  of Set 1 | carnarvon.
# Processing Record 1  of Set 1 | terrace bay.
# Processing Record 1  of Set 1 | gravdal.
# Processing Record 1  of Set 1 | albany.
# Processing Record 1  of Set 1 | along.
# Processing Record 1  of Set 1 | georgetown.
# Processing Record 1  of Set 1 | port elizabeth.
# Processing Record 1  of Set 1 | esperance.
# Processing Record 1  of Set 1 | jamestown.
# Processing Record 1  of Set 1 | yellowknife.
# Processing Record 1  of Set 1 | port alfred.
# Processing Record 1  of Set 1 | basco.
# Processing Record 1  of Set 1 | hwange.
# Processing Record 1  of Set 1 | sarahan.
# Processing Record 1  of Set 1 | new braunfels.
# Processing Record 1  of Set 1 | vila do maio.
# Processing Record 1  of Set 1 | saint george.
# Processing Record 1  of Set 1 | filadelfia.
# Processing Record 1  of Set 1 | kang.
# Processing Record 1  of Set 1 | kapaa.
# Processing Record 1  of Set 1 | puerto ayora.
# Processing Record 1  of Set 1 | ushuaia.
# Processing Record 1  of Set 1 | nizhneyansk.
# City not found...skipping.
# Processing Record 1  of Set 1 | cabo san lucas.
# Processing Record 1  of Set 1 | rikitea.
# Processing Record 1  of Set 1 | taolanaro.
# City not found...skipping.
# Processing Record 1  of Set 1 | port blair.
# Processing Record 1  of Set 1 | hofn.
# Processing Record 1  of Set 1 | west bay.
# Processing Record 1  of Set 1 | bredasdorp.
# Processing Record 1  of Set 1 | milingimbi.
# City not found...skipping.
# Processing Record 1  of Set 1 | hilo.
# Processing Record 1  of Set 1 | upernavik.
# Processing Record 1  of Set 1 | arcachon.
# Processing Record 1  of Set 1 | lavrentiya.
# Processing Record 1  of Set 1 | porosozero.
# Processing Record 1  of Set 1 | vaitupu.
# City not found...skipping.
# Processing Record 1  of Set 1 | nome.
# Processing Record 1  of Set 1 | geraldton.
# Processing Record 1  of Set 1 | barrow.
# Processing Record 1  of Set 1 | bambous virieux.
# Processing Record 1  of Set 1 | kruisfontein.
# Processing Record 1  of Set 1 | east london.
# Processing Record 1  of Set 1 | gazli.
# Processing Record 1  of Set 1 | saleaula.
# City not found...skipping.
# Processing Record 1  of Set 1 | nanortalik.
# Processing Record 1  of Set 1 | cape town.
# Processing Record 1  of Set 1 | avarua.
# Processing Record 1  of Set 1 | hermanus.
# Processing Record 1  of Set 1 | srednekolymsk.
# Processing Record 1  of Set 1 | zabaykalsk.
# Processing Record 1  of Set 1 | tianpeng.
# Processing Record 1  of Set 1 | bluff.
# Processing Record 1  of Set 1 | faanui.
# Processing Record 1  of Set 1 | warqla.
# City not found...skipping.
# Processing Record 1  of Set 1 | asau.
# City not found...skipping.
# Processing Record 1  of Set 1 | klaksvik.
# Processing Record 1  of Set 1 | rangapara.
# Processing Record 1  of Set 1 | sao felix do xingu.
# Processing Record 1  of Set 1 | aswan.
# Processing Record 1  of Set 1 | clyde river.
# Processing Record 1  of Set 1 | santiago.
# Processing Record 1  of Set 1 | rio claro.
# Processing Record 1  of Set 1 | awbari.
# Processing Record 1  of Set 1 | tomatlan.
# Processing Record 1  of Set 1 | walvis bay.
# Processing Record 1  of Set 1 | tiksi.
# Processing Record 1  of Set 1 | dzilam gonzalez.
# Processing Record 1  of Set 1 | moussoro.
# Processing Record 1  of Set 1 | andapa.
# Processing Record 1  of Set 1 | broome.
# Processing Record 1  of Set 1 | victoria.
# Processing Record 1  of Set 1 | crab hill.
# City not found...skipping.
# Processing Record 1  of Set 1 | kodiak.
# Processing Record 1  of Set 1 | leningradskiy.
# Processing Record 1  of Set 1 | atuona.
# Processing Record 1  of Set 1 | artyom.
# Processing Record 1  of Set 1 | hami.
# Processing Record 1  of Set 1 | chupa.
# Processing Record 1  of Set 1 | cody.
# Processing Record 1  of Set 1 | tilichiki.
# Processing Record 1  of Set 1 | saint-philippe.
# Processing Record 1  of Set 1 | attawapiskat.
# City not found...skipping.
# Processing Record 1  of Set 1 | qaanaaq.
# Processing Record 1  of Set 1 | illoqqortoormiut.
# City not found...skipping.
# Processing Record 1  of Set 1 | souillac.
# Processing Record 1  of Set 1 | kailua.
# Processing Record 1  of Set 1 | lekoni.
# Processing Record 1  of Set 1 | barentsburg.
# City not found...skipping.
# Processing Record 1  of Set 1 | luderitz.
# Processing Record 1  of Set 1 | mrirt.
# City not found...skipping.
# Processing Record 1  of Set 1 | tsihombe.
# City not found...skipping.
# Processing Record 1  of Set 1 | sitka.
# Processing Record 1  of Set 1 | punta arenas.
# Processing Record 1  of Set 1 | ribeira grande.
# Processing Record 1  of Set 1 | ixtapa.
# Processing Record 1  of Set 1 | hualmay.
# Processing Record 1  of Set 1 | aiquile.
# Processing Record 1  of Set 1 | beloha.
# Processing Record 1  of Set 1 | butaritari.
# Processing Record 1  of Set 1 | maceio.
# Processing Record 1  of Set 1 | dunedin.
# Processing Record 1  of Set 1 | north platte.
# Processing Record 1  of Set 1 | belushya guba.
# City not found...skipping.
# Processing Record 1  of Set 1 | prainha.
# Processing Record 1  of Set 1 | san jose de gracia.
# Processing Record 1  of Set 1 | husavik.
# Processing Record 1  of Set 1 | torbay.
# Processing Record 1  of Set 1 | lhokseumawe.
# Processing Record 1  of Set 1 | dikson.
# Processing Record 1  of Set 1 | strausberg.
# Processing Record 1  of Set 1 | temaraia.
# City not found...skipping.
# Processing Record 1  of Set 1 | khatanga.
# Processing Record 1  of Set 1 | hobart.
# Processing Record 1  of Set 1 | umarizal.
# Processing Record 1  of Set 1 | nishihara.
# Processing Record 1  of Set 1 | amderma.
# City not found...skipping.
# Processing Record 1  of Set 1 | umzimvubu.
# City not found...skipping.
# Processing Record 1  of Set 1 | saint-pierre.
# Processing Record 1  of Set 1 | axim.
# Processing Record 1  of Set 1 | cherskiy.
# Processing Record 1  of Set 1 | najran.
# Processing Record 1  of Set 1 | komsomolskiy.
# Processing Record 1  of Set 1 | lasa.
# Processing Record 1  of Set 1 | udachnyy.
# Processing Record 1  of Set 1 | new norfolk.
# Processing Record 1  of Set 1 | campbell river.
# Processing Record 1  of Set 1 | kununurra.
# Processing Record 1  of Set 1 | san cristobal.
# Processing Record 1  of Set 1 | kavaratti.
# Processing Record 1  of Set 1 | camacha.
# Processing Record 1  of Set 1 | cordoba.
# Processing Record 1  of Set 1 | nyurba.
# Processing Record 1  of Set 1 | lorengau.
# Processing Record 1  of Set 1 | tatarsk.
# Processing Record 1  of Set 1 | kieta.
# Processing Record 1  of Set 1 | herat.
# Processing Record 1  of Set 1 | prince george.
# Processing Record 1  of Set 1 | vilhena.
# Processing Record 1  of Set 1 | tumannyy.
# City not found...skipping.
# Processing Record 1  of Set 1 | cidreira.
# Processing Record 1  of Set 1 | kahului.
# Processing Record 1  of Set 1 | falealupo.
# City not found...skipping.
# Processing Record 1  of Set 1 | panguna.
# Processing Record 1  of Set 1 | arraial do cabo.
# Processing Record 1  of Set 1 | alofi.
# Processing Record 1  of Set 1 | honiara.
# Processing Record 1  of Set 1 | hay river.
# Processing Record 1  of Set 1 | thompson.
# Processing Record 1  of Set 1 | namtsy.
# Processing Record 1  of Set 1 | charyshskoye.
# Processing Record 1  of Set 1 | omsukchan.
# Processing Record 1  of Set 1 | abu samrah.
# Processing Record 1  of Set 1 | lokosovo.
# Processing Record 1  of Set 1 | codrington.
# Processing Record 1  of Set 1 | quesnel.
# Processing Record 1  of Set 1 | jacareacanga.
# Processing Record 1  of Set 1 | aflu.
# City not found...skipping.
# Processing Record 1  of Set 1 | shimoni.
# Processing Record 1  of Set 1 | half moon bay.
# Processing Record 1  of Set 1 | mys shmidta.
# City not found...skipping.
# Processing Record 1  of Set 1 | kargasok.
# Processing Record 1  of Set 1 | sibiti.
# Processing Record 1  of Set 1 | solnechnyy.
# Processing Record 1  of Set 1 | rassvet.
# Processing Record 1  of Set 1 | siddharthanagar.
# City not found...skipping.
# Processing Record 1  of Set 1 | yulara.
# Processing Record 1  of Set 1 | tyrma.
# Processing Record 1  of Set 1 | padang.
# Processing Record 1  of Set 1 | zhezkazgan.
# Processing Record 1  of Set 1 | povenets.
# Processing Record 1  of Set 1 | mitsamiouli.
# Processing Record 1  of Set 1 | ambilobe.
# Processing Record 1  of Set 1 | auki.
# Processing Record 1  of Set 1 | kaitangata.
# Processing Record 1  of Set 1 | hasaki.
# Processing Record 1  of Set 1 | batagay-alyta.
# Processing Record 1  of Set 1 | castro.
# Processing Record 1  of Set 1 | omboue.
# Processing Record 1  of Set 1 | sena madureira.
# Processing Record 1  of Set 1 | khandyga.
# Processing Record 1  of Set 1 | hobyo.
# Processing Record 1  of Set 1 | akyab.
# City not found...skipping.
# Processing Record 1  of Set 1 | linxia.
# Processing Record 1  of Set 1 | jizan.
# Processing Record 1  of Set 1 | boffa.
# Processing Record 1  of Set 1 | gat.
# Processing Record 1  of Set 1 | caruray.
# Processing Record 1  of Set 1 | zinder.
# Processing Record 1  of Set 1 | beira.
# Processing Record 1  of Set 1 | tasiilaq.
# Processing Record 1  of Set 1 | hailey.
# Processing Record 1  of Set 1 | trairi.
# Processing Record 1  of Set 1 | the valley.
# Processing Record 1  of Set 1 | henties bay.
# Processing Record 1  of Set 1 | genhe.
# Processing Record 1  of Set 1 | grand river south east.
# City not found...skipping.
# Processing Record 1  of Set 1 | tongren.
# Processing Record 1  of Set 1 | pisco.
# Processing Record 1  of Set 1 | atlantic city.
# City not found...skipping.
# Processing Record 1  of Set 1 | shimoda.
# Processing Record 1  of Set 1 | huarmey.
# Processing Record 1  of Set 1 | sorong.
# Processing Record 1  of Set 1 | zuwarah.
# Processing Record 1  of Set 1 | aklavik.
# Processing Record 1  of Set 1 | san quintin.
# Processing Record 1  of Set 1 | lithakia.
# Processing Record 1  of Set 1 | ranfurly.
# Processing Record 1  of Set 1 | taoudenni.
# Processing Record 1  of Set 1 | hithadhoo.
# Processing Record 1  of Set 1 | brae.
# Processing Record 1  of Set 1 | berlevag.
# Processing Record 1  of Set 1 | muros.
# Processing Record 1  of Set 1 | tautira.
# Processing Record 1  of Set 1 | labuan.
# Processing Record 1  of Set 1 | marzuq.
# Processing Record 1  of Set 1 | ahipara.
# Processing Record 1  of Set 1 | usta muhammad.
# Processing Record 1  of Set 1 | tual.
# Processing Record 1  of Set 1 | hof.
# Processing Record 1  of Set 1 | pangnirtung.
# Processing Record 1  of Set 1 | bathsheba.
# Processing Record 1  of Set 1 | batemans bay.
# Processing Record 1  of Set 1 | kapiri mposhi.
# Processing Record 1  of Set 1 | shimanovsk.
# Processing Record 1  of Set 1 | vila franca do campo.
# Processing Record 1  of Set 1 | deputatskiy.
# Processing Record 1  of Set 1 | cayenne.
# Processing Record 1  of Set 1 | salalah.
# Processing Record 1  of Set 1 | bonthe.
# Processing Record 1  of Set 1 | constitucion.
# Processing Record 1  of Set 1 | toora-khem.
# Processing Record 1  of Set 1 | obarsia-closani.
# City not found...skipping.
# Processing Record 1  of Set 1 | vicksburg.
# Processing Record 1  of Set 1 | wajima.
# Processing Record 1  of Set 1 | aykhal.
# Processing Record 1  of Set 1 | meulaboh.
# Processing Record 1  of Set 1 | harrisonburg.
# Processing Record 1  of Set 1 | coquimbo.
# Processing Record 1  of Set 1 | pitimbu.
# Processing Record 1  of Set 1 | rocha.
# Processing Record 1  of Set 1 | quimper.
# Processing Record 1  of Set 1 | touros.
# Processing Record 1  of Set 1 | kavieng.
# Processing Record 1  of Set 1 | kenai.
# Processing Record 1  of Set 1 | bara.
# Processing Record 1  of Set 1 | ancud.
# Processing Record 1  of Set 1 | flinders.
# Processing Record 1  of Set 1 | karaul.
# City not found...skipping.
# Processing Record 1  of Set 1 | talnakh.
# Processing Record 1  of Set 1 | victoria point.
# Processing Record 1  of Set 1 | serov.
# Processing Record 1  of Set 1 | mount gambier.
# Processing Record 1  of Set 1 | samarai.
# Processing Record 1  of Set 1 | indianola.
# Processing Record 1  of Set 1 | bubaque.
# Processing Record 1  of Set 1 | inhambane.
# Processing Record 1  of Set 1 | karatau.
# Processing Record 1  of Set 1 | dunayivtsi.
# City not found...skipping.
# Processing Record 1  of Set 1 | kiruna.
# Processing Record 1  of Set 1 | katsiveli.
# City not found...skipping.
# Processing Record 1  of Set 1 | sola.
# Processing Record 1  of Set 1 | fayaoue.
# Processing Record 1  of Set 1 | karwar.
# Processing Record 1  of Set 1 | constantine.
# Processing Record 1  of Set 1 | sao jose da coroa grande.
# Processing Record 1  of Set 1 | sabang.
# Processing Record 1  of Set 1 | bacuit.
# City not found...skipping.
# Processing Record 1  of Set 1 | sosnovskiy.
# City not found...skipping.
# Processing Record 1  of Set 1 | bethel.
# Processing Record 1  of Set 1 | osorno.
# Processing Record 1  of Set 1 | rudbar.
# City not found...skipping.
# Processing Record 1  of Set 1 | aligudarz.
# Processing Record 1  of Set 1 | palauig.
# Processing Record 1  of Set 1 | cavalcante.
# Processing Record 1  of Set 1 | jinchang.
# Processing Record 1  of Set 1 | katsuura.
# Processing Record 1  of Set 1 | inirida.
# Processing Record 1  of Set 1 | milkovo.
# Processing Record 1  of Set 1 | chuy.
# Processing Record 1  of Set 1 | nadym.
# Processing Record 1  of Set 1 | tukrah.
# City not found...skipping.
# Processing Record 1  of Set 1 | nalut.
# Processing Record 1  of Set 1 | acarau.
# City not found...skipping.
# Processing Record 1  of Set 1 | lagoa.
# Processing Record 1  of Set 1 | calama.
# Processing Record 1  of Set 1 | umm kaddadah.
# Processing Record 1  of Set 1 | baryatino.
# Processing Record 1  of Set 1 | hermosillo.
# Processing Record 1  of Set 1 | madang.
# Processing Record 1  of Set 1 | mahebourg.
# Processing Record 1  of Set 1 | muyezerskiy.
# Processing Record 1  of Set 1 | skowhegan.
# Processing Record 1  of Set 1 | zig.
# Processing Record 1  of Set 1 | wakkanai.
# Processing Record 1  of Set 1 | rungata.
# City not found...skipping.
# Processing Record 1  of Set 1 | samusu.
# City not found...skipping.
# Processing Record 1  of Set 1 | bur gabo.
# City not found...skipping.
# Processing Record 1  of Set 1 | pingliang.
# Processing Record 1  of Set 1 | concepcion del oro.
# Processing Record 1  of Set 1 | pevek.
# Processing Record 1  of Set 1 | killybegs.
# Processing Record 1  of Set 1 | rapid valley.
# Processing Record 1  of Set 1 | mount isa.
# Processing Record 1  of Set 1 | merauke.
# Processing Record 1  of Set 1 | assiniboia.
# Processing Record 1  of Set 1 | hovd.
# Processing Record 1  of Set 1 | nurota.
# Processing Record 1  of Set 1 | bad munder.
# City not found...skipping.
# Processing Record 1  of Set 1 | shamkhal.
# Processing Record 1  of Set 1 | gladstone.
# Processing Record 1  of Set 1 | piltene.
# Processing Record 1  of Set 1 | carbonia.
# Processing Record 1  of Set 1 | porto novo.
# Processing Record 1  of Set 1 | rodino.
# Processing Record 1  of Set 1 | asyut.
# Processing Record 1  of Set 1 | chardara.
# City not found...skipping.
# Processing Record 1  of Set 1 | vestmannaeyjar.
# Processing Record 1  of Set 1 | male.
# Processing Record 1  of Set 1 | castres.
# Processing Record 1  of Set 1 | anadyr.
# Processing Record 1  of Set 1 | terrace.
# Processing Record 1  of Set 1 | zhuhai.
# Processing Record 1  of Set 1 | new baltimore.
# Processing Record 1  of Set 1 | tabas.
# Processing Record 1  of Set 1 | laguna.
# Processing Record 1  of Set 1 | sentyabrskiy.
# City not found...skipping.
# Processing Record 1  of Set 1 | jujuy.
# City not found...skipping.
# Processing Record 1  of Set 1 | san policarpo.
# Processing Record 1  of Set 1 | matara.
# Processing Record 1  of Set 1 | narsaq.
# Processing Record 1  of Set 1 | burnie.
# Processing Record 1  of Set 1 | opunake.
# Processing Record 1  of Set 1 | chilliwack.
# Processing Record 1  of Set 1 | ust-kut.
# Processing Record 1  of Set 1 | longyearbyen.
# Processing Record 1  of Set 1 | gurlan.
# Processing Record 1  of Set 1 | pinega.
# Processing Record 1  of Set 1 | port hedland.
# Processing Record 1  of Set 1 | biak.
# Processing Record 1  of Set 1 | turukhansk.
# Processing Record 1  of Set 1 | iqaluit.
# Processing Record 1  of Set 1 | novolakskoye.
# Processing Record 1  of Set 1 | jutai.
# Processing Record 1  of Set 1 | tres arroyos.
# Processing Record 1  of Set 1 | prabumulih.
# Processing Record 1  of Set 1 | necochea.
# Processing Record 1  of Set 1 | estelle.
# Processing Record 1  of Set 1 | bachaquero.
# Processing Record 1  of Set 1 | chiredzi.
# Processing Record 1  of Set 1 | gejiu.
# Processing Record 1  of Set 1 | broken hill.
# Processing Record 1  of Set 1 | saldanha.
# Processing Record 1  of Set 1 | rochegda.
# Processing Record 1  of Set 1 | waingapu.
# Processing Record 1  of Set 1 | saint-augustin.
# Processing Record 1  of Set 1 | ko samui.
# Processing Record 1  of Set 1 | biloela.
# Processing Record 1  of Set 1 | jalu.
# Processing Record 1  of Set 1 | sept-iles.
# Processing Record 1  of Set 1 | saint-georges.
# Processing Record 1  of Set 1 | moose factory.
# Processing Record 1  of Set 1 | great falls.
# Processing Record 1  of Set 1 | labuhan.
# Processing Record 1  of Set 1 | zarichne.
# Processing Record 1  of Set 1 | marfino.
# Processing Record 1  of Set 1 | taltal.
# Processing Record 1  of Set 1 | lebu.
# Processing Record 1  of Set 1 | bellevue.
# Processing Record 1  of Set 1 | norman wells.
# Processing Record 1  of Set 1 | ilulissat.
# Processing Record 1  of Set 1 | norilsk.
# Processing Record 1  of Set 1 | arlit.
# Processing Record 1  of Set 1 | kudymkar.
# Processing Record 1  of Set 1 | neuquen.
# Processing Record 1  of Set 1 | bandarbeyla.
# Processing Record 1  of Set 1 | airai.
# Processing Record 1  of Set 1 | kudahuvadhoo.
# Processing Record 1  of Set 1 | mahadday weyne.
# City not found...skipping.
# Processing Record 1  of Set 1 | melekhovskaya.
# City not found...skipping.
# Processing Record 1  of Set 1 | acapulco.
# Processing Record 1  of Set 1 | sawakin.
# Processing Record 1  of Set 1 | san rafael.
# Processing Record 1  of Set 1 | pasir gudang.
# Processing Record 1  of Set 1 | ilhabela.
# Processing Record 1  of Set 1 | pitkyaranta.
# Processing Record 1  of Set 1 | skibbereen.
# Processing Record 1  of Set 1 | rawson.
# Processing Record 1  of Set 1 | bourail.
# Processing Record 1  of Set 1 | skiros.
# City not found...skipping.
# Processing Record 1  of Set 1 | sivaki.
# Processing Record 1  of Set 1 | bonnyville.
# Processing Record 1  of Set 1 | qandala.
# Processing Record 1  of Set 1 | yenagoa.
# Processing Record 1  of Set 1 | mezen.
# Processing Record 1  of Set 1 | huangchuan.
# Processing Record 1  of Set 1 | anajatuba.
# Processing Record 1  of Set 1 | quatre cocos.
# Processing Record 1  of Set 1 | gazni.
# City not found...skipping.
# Processing Record 1  of Set 1 | lebane.
# Processing Record 1  of Set 1 | morant bay.
# Processing Record 1  of Set 1 | raudeberg.
# Processing Record 1  of Set 1 | kilrush.
# Processing Record 1  of Set 1 | vao.
# Processing Record 1  of Set 1 | dogondoutchi.
# Processing Record 1  of Set 1 | port macquarie.
# Processing Record 1  of Set 1 | sao filipe.
# Processing Record 1  of Set 1 | carutapera.
# Processing Record 1  of Set 1 | fort nelson.
# Processing Record 1  of Set 1 | darnah.
# Processing Record 1  of Set 1 | trindade.
# Processing Record 1  of Set 1 | great bend.
# Processing Record 1  of Set 1 | kamenskoye.
# City not found...skipping.
# Processing Record 1  of Set 1 | bacolod.
# Processing Record 1  of Set 1 | puerto escondido.
# Processing Record 1  of Set 1 | westport.
# Processing Record 1  of Set 1 | sibolga.
# Processing Record 1  of Set 1 | barreirinhas.
# Processing Record 1  of Set 1 | seymchan.
# Processing Record 1  of Set 1 | sumbawa.
# City not found...skipping.
# Processing Record 1  of Set 1 | meadow lake.
# Processing Record 1  of Set 1 | yumen.
# Processing Record 1  of Set 1 | kingman.
# Processing Record 1  of Set 1 | lolua.
# City not found...skipping.
# Processing Record 1  of Set 1 | abu zabad.
# Processing Record 1  of Set 1 | isangel.
# Processing Record 1  of Set 1 | lityn.
# Processing Record 1  of Set 1 | maniitsoq.
# Processing Record 1  of Set 1 | mar del plata.
# Processing Record 1  of Set 1 | dingle.
# Processing Record 1  of Set 1 | les cayes.
# Processing Record 1  of Set 1 | san patricio.
# Processing Record 1  of Set 1 | steamboat springs.
# Processing Record 1  of Set 1 | misratah.
# Processing Record 1  of Set 1 | malanje.
# Processing Record 1  of Set 1 | khash.
# Processing Record 1  of Set 1 | naze.
# Processing Record 1  of Set 1 | mahaicony.
# City not found...skipping.
# Processing Record 1  of Set 1 | sovetskiy.
# Processing Record 1  of Set 1 | catuday.
# Processing Record 1  of Set 1 | fort smith.
# Processing Record 1  of Set 1 | tubuala.
# Processing Record 1  of Set 1 | camabatela.
# Processing Record 1  of Set 1 | kasongo-lunda.
# Processing Record 1  of Set 1 | alice springs.
# Processing Record 1  of Set 1 | lulea.
# Processing Record 1  of Set 1 | cap malheureux.
# Processing Record 1  of Set 1 | mayo.
# Processing Record 1  of Set 1 | gamba.
# Processing Record 1  of Set 1 | lokeren.
# Processing Record 1  of Set 1 | yerbogachen.
# Processing Record 1  of Set 1 | forbes.
# Processing Record 1  of Set 1 | romny.
# Processing Record 1  of Set 1 | sarkand.
# Processing Record 1  of Set 1 | xuddur.
# Processing Record 1  of Set 1 | shunyi.
# Processing Record 1  of Set 1 | srednyaya akhtuba.
# Processing Record 1  of Set 1 | hirara.
# Processing Record 1  of Set 1 | baykit.
# Processing Record 1  of Set 1 | shache.
# Processing Record 1  of Set 1 | ponta delgada.
# Processing Record 1  of Set 1 | provideniya.
# Processing Record 1  of Set 1 | hokitika.
# Processing Record 1  of Set 1 | lompoc.
# Processing Record 1  of Set 1 | gorele.
# Processing Record 1  of Set 1 | grindavik.
# Processing Record 1  of Set 1 | portland.
# Processing Record 1  of Set 1 | asosa.
# Processing Record 1  of Set 1 | shihezi.
# Processing Record 1  of Set 1 | ijaki.
# City not found...skipping.
# Processing Record 1  of Set 1 | bela.
# Processing Record 1  of Set 1 | tzucacab.
# Processing Record 1  of Set 1 | issoudun.
# Processing Record 1  of Set 1 | iguape.
# Processing Record 1  of Set 1 | fortuna.
# Processing Record 1  of Set 1 | yangambi.
# Processing Record 1  of Set 1 | haines junction.
# Processing Record 1  of Set 1 | bolungarvik.
# City not found...skipping.
# Processing Record 1  of Set 1 | balykshi.
# City not found...skipping.
# Processing Record 1  of Set 1 | opuwo.
# Processing Record 1  of Set 1 | tevriz.
# Processing Record 1  of Set 1 | san vicente de chucuri.
# Processing Record 1  of Set 1 | pacific grove.
# Processing Record 1  of Set 1 | kokstad.
# Processing Record 1  of Set 1 | codajas.
# Processing Record 1  of Set 1 | montlucon.
# Processing Record 1  of Set 1 | hayden.
# Processing Record 1  of Set 1 | popondetta.
# Processing Record 1  of Set 1 | beringovskiy.
# Processing Record 1  of Set 1 | corum.
# Processing Record 1  of Set 1 | tuy hoa.
# Processing Record 1  of Set 1 | khasan.
# Processing Record 1  of Set 1 | miracema do tocantins.
# Processing Record 1  of Set 1 | rincon de la victoria.
# Processing Record 1  of Set 1 | hlotse.
# City not found...skipping.
# Processing Record 1  of Set 1 | brasilia de minas.
# Processing Record 1  of Set 1 | santa ana.
# Processing Record 1  of Set 1 | dongsheng.
# Processing Record 1  of Set 1 | kenitra.
# Processing Record 1  of Set 1 | mehamn.
# Processing Record 1  of Set 1 | manaure.
# Processing Record 1  of Set 1 | scottsboro.
# Processing Record 1  of Set 1 | stekolnyy.
# City not found...skipping.
# Processing Record 1  of Set 1 | tuzha.
# Processing Record 1  of Set 1 | sur.
# Processing Record 1  of Set 1 | bozeman.
# Processing Record 1  of Set 1 | mahon.
# Processing Record 1  of Set 1 | srivardhan.
# Processing Record 1  of Set 1 | red bank.
# Processing Record 1  of Set 1 | raymondville.
# Processing Record 1  of Set 1 | micheweni.
# Processing Record 1  of Set 1 | goderich.
# Processing Record 1  of Set 1 | sulangan.
# Processing Record 1  of Set 1 | changji.
# Processing Record 1  of Set 1 | werota.
# Processing Record 1  of Set 1 | desaguadero.
# Processing Record 1  of Set 1 | petropavlovka.
# Processing Record 1  of Set 1 | fare.
# Processing Record 1  of Set 1 | moralillo.
# Processing Record 1  of Set 1 | chapais.
# Processing Record 1  of Set 1 | hunza.
# City not found...skipping.
# Processing Record 1  of Set 1 | tezu.
# Processing Record 1  of Set 1 | zhigansk.
# Processing Record 1  of Set 1 | panama city.
# Processing Record 1  of Set 1 | kamyshevatskaya.
# Processing Record 1  of Set 1 | yelizavetino.
# Processing Record 1  of Set 1 | riyadh.
# Processing Record 1  of Set 1 | ingham.
# Processing Record 1  of Set 1 | fereydunshahr.
# Processing Record 1  of Set 1 | tuatapere.
# Processing Record 1  of Set 1 | saint anthony.
# Processing Record 1  of Set 1 | mokhsogollokh.
# Processing Record 1  of Set 1 | karpogory.
# Processing Record 1  of Set 1 | macenta.
# Processing Record 1  of Set 1 | pingdingshan.
# Processing Record 1  of Set 1 | alta floresta.
# Processing Record 1  of Set 1 | khoy.
# Processing Record 1  of Set 1 | palabuhanratu.
# City not found...skipping.
# Processing Record 1  of Set 1 | shingu.
# Processing Record 1  of Set 1 | nizhniy kuranakh.
# Processing Record 1  of Set 1 | ikwiriri.
# Processing Record 1  of Set 1 | fuerte olimpo.
# Processing Record 1  of Set 1 | zaozerne.
# Processing Record 1  of Set 1 | viedma.
# Processing Record 1  of Set 1 | ngukurr.
# City not found...skipping.
# Processing Record 1  of Set 1 | wonthaggi.
# Processing Record 1  of Set 1 | comodoro rivadavia.
# Processing Record 1  of Set 1 | state college.
# Processing Record 1  of Set 1 | college.
# Processing Record 1  of Set 1 | ginir.
# Processing Record 1  of Set 1 | ugoofaaru.
# Processing Record 1  of Set 1 | catumbela.
# Processing Record 1  of Set 1 | dolbeau.
# City not found...skipping.
# Processing Record 1  of Set 1 | chifeng.
# Processing Record 1  of Set 1 | fort saint james.
# Processing Record 1  of Set 1 | vanino.
# Processing Record 1  of Set 1 | zhanaozen.
# Processing Record 1  of Set 1 | joshimath.
# Processing Record 1  of Set 1 | zapolyarnyy.
# Processing Record 1  of Set 1 | nagato.
# Processing Record 1  of Set 1 | kautokeino.
# Processing Record 1  of Set 1 | yuzhno-yeniseyskiy.
# City not found...skipping.
# Processing Record 1  of Set 1 | muisne.
# Processing Record 1  of Set 1 | cazaje.
# City not found...skipping.
# Processing Record 1  of Set 1 | lagunas.
# Processing Record 1  of Set 1 | nioki.
# Processing Record 1  of Set 1 | goundam.
# Processing Record 1  of Set 1 | weligama.
# Processing Record 1  of Set 1 | thoen.
# Processing Record 1  of Set 1 | iralaya.
# Processing Record 1  of Set 1 | vila.
# Processing Record 1  of Set 1 | pithora.
# Processing Record 1  of Set 1 | tura.
# Processing Record 1  of Set 1 | balkhash.
# Processing Record 1  of Set 1 | nelson bay.
# Processing Record 1  of Set 1 | adrar.
# Processing Record 1  of Set 1 | yermish.
# Processing Record 1  of Set 1 | faridabad.
# Processing Record 1  of Set 1 | oranjemund.
# Processing Record 1  of Set 1 | derzhavinsk.
# Processing Record 1  of Set 1 | byron bay.
# Processing Record 1  of Set 1 | birao.
# Processing Record 1  of Set 1 | samana.
# Processing Record 1  of Set 1 | nhulunbuy.
# Processing Record 1  of Set 1 | kismayo.
# City not found...skipping.
# Processing Record 1  of Set 1 | mariental.
# Processing Record 1  of Set 1 | ust-bolsheretsk.
# City not found...skipping.
# Processing Record 1  of Set 1 | hanzhong.
# Processing Record 1  of Set 1 | ambon.
# Processing Record 1  of Set 1 | wanaka.
# Processing Record 1  of Set 1 | kutum.
# Processing Record 1  of Set 1 | namibe.
# Processing Record 1  of Set 1 | sendafa.
# Processing Record 1  of Set 1 | yar-sale.
# Processing Record 1  of Set 1 | moron.
# Processing Record 1  of Set 1 | obo.
# Processing Record 1  of Set 1 | karamay.
# City not found...skipping.
# Processing Record 1  of Set 1 | masterton.
# Processing Record 1  of Set 1 | ekibastuz.
# Processing Record 1  of Set 1 | chokurdakh.
# Processing Record 1  of Set 1 | nemuro.
# Processing Record 1  of Set 1 | areia branca.
# Processing Record 1  of Set 1 | coihaique.
# Processing Record 1  of Set 1 | lang suan.
# Processing Record 1  of Set 1 | namatanai.
# Processing Record 1  of Set 1 | pandan.
# Processing Record 1  of Set 1 | tucumcari.
# Processing Record 1  of Set 1 | devils lake.
# Processing Record 1  of Set 1 | the pas.
# Processing Record 1  of Set 1 | skalistyy.
# City not found...skipping.
# Processing Record 1  of Set 1 | buchanan.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Getting Counts
weather= pd.DataFrame(weather_df)
weather.count()
# Out:
# City          623
# Cloudiness    623
# Country       623
# Date          623
# Humidity      623
# Lat           623
# Lon           623
# Max Temp      623
# Wind Speed    623
# dtype: int64

# %%
#Displaying Dataframe
weather= pd.DataFrame(weather_df)
weather.head()
# Out:
#           City Cloudiness Country        Date Humidity    Lat     Lon  \
# 0   nikolskoye         90      RU  1569447892       93   59.7   30.79
# 1    havoysund         75      NO  1569447892       87     71   24.66
# 2   port hardy         90      CA  1569447892       93   50.7 -127.42
# 3        vaini        100      IN  1569447715       95  15.34   74.49
# 4  tuktoyaktuk         75      CA  1569447892       86  69.44 -133.03
#
#   Max Temp Wind Speed
# 0     39.2       2.24
# 1     44.6      10.29
# 2     51.8      11.41
# 3    75.29       2.33
# 4       41        4.7

# %%
weather.replace("", np.nan, inplace = True)
weather = weather_df.dropna()
weather.head()
print(f"There are {len(weather)} cities included in the weather analyses.")
# Out:
# There are 557 cities included in the weather analyses.

# %%
#Exporting city data into a csv file
weather.to_csv("weather_output.csv", index=False, encoding='utf-8')
weather.dropna()
# Out:
#                    City Cloudiness Country        Date Humidity    Lat  \
# 0               tubuala         40      PA  1569373398       94   9.52
# 1            nikolskoye          0      RU  1569373398       94   59.7
# 2                nacala          0      MZ  1569373398       96 -14.56
# 3               remanso         85      BR  1569373398       43  -9.62
# 4                maceio         20      BR  1569373222       83  -9.67
# 5               ushuaia         75      AR  1569373240       70 -54.81
# 6                torbay         90      CA  1569373398       93  47.66
# 7            mandalgovi         57      MN  1569373399       29  45.76
# 9                 ancud          0      CL  1569373399      100 -41.87
# 10              kavieng        100      PG  1569373399       68  -2.57
# 11              aklavik         40      CA  1569373399       61  68.22
# 12               hobart         75      AU  1569373165       46 -42.88
# 13              mataura        100      NZ  1569373399       75 -46.19
# 14       krasnyy chikoy          0      RU  1569373400       77  50.36
# 15            zacatepec         84      MX  1569373400       88  20.06
# 16               naples         20      IT  1569373400       88  40.84
# 17                bowen         40      AU  1569373400       54 -20.01
# 18                bluff         45      AU  1569373400       53 -23.58
# 19              sorland         61      NO  1569373400       50  67.67
# 20           chokurdakh          0      RU  1569373400       62  70.62
# 21              dunedin         94      NZ  1569373145       71 -45.87
# 22            jamestown          0      AU  1569373401       53 -33.21
# 23           georgetown         40      GY  1569373349       74    6.8
# 24         kudahuvadhoo        100      MV  1569373406       76   2.67
# 27             klaksvik        100      FO  1569373406      100  62.23
# 28            esperance         52      AU  1569373407       36 -33.86
# 29               qujing        100      CN  1569373407       88  25.49
# 30            cape town          0      ZA  1569373207       76 -33.93
# 33                sibut        100      CF  1569373408       88   5.73
# 34               albany         90      US  1569373371       93  42.65
# ..                  ...        ...     ...         ...      ...    ...
# 588           wojkowice         20      PL  1569373236       93  50.37
# 589         znamenskoye         39      RU  1569373483       97  57.13
# 591               bayan          7      CN  1569373483       67   36.1
# 592         trincomalee         90      LK  1569373483       91   8.58
# 593             worland          1      US  1569373388       28  44.02
# 594              kargil          0      PK  1569373483       63  34.56
# 595             huarmey         49      PE  1569373483       93 -10.07
# 596             methoni          0      GR  1569373483       88  36.82
# 597              vokhma         95      RU  1569373484       94  58.93
# 598          nueva loja        100      EC  1569373484       84   0.08
# 599          baijiantan        100      CN  1569373484       34  45.63
# 600           vestmanna        100      FO  1569373484      100  62.16
# 601         pundaguitan         22      PH  1569373484       75   6.37
# 602         verkhoyansk         58      RU  1569373484       82  67.55
# 603         charlestown         40      US  1569373484       55  41.38
# 604             manggar         25      ID  1569373485       73  -2.88
# 605          sao filipe        100      CV  1569373485       90   14.9
# 607               mopti          0      ML  1569373485       84  14.49
# 608            vondrozo         53      MG  1569373485       96 -22.82
# 609               sabha          0      LY  1569373485       22  27.03
# 610  severo-yeniseyskiy         17      RU  1569373485       93  60.37
# 611               altay         82      CN  1569373485       45  47.83
# 613      nisia floresta          0      BR  1569373486       78  -6.09
# 614             aljezur         22      PT  1569373486       96  37.31
# 615                inta        100      RU  1569373486       96  66.04
# 616              nemuro         20      JP  1569373486       52  43.32
# 617             parabel        100      RU  1569373486       92  58.71
# 618           yagodnoye        100      RU  1569373486       57  62.52
# 619    twentynine palms          1      US  1569373487       19  34.14
# 620     krasnoshchekovo         91      RU  1569373487       74  51.67
#
#         Lon Max Temp Wind Speed
# 0    -79.03       81       2.24
# 1     30.79       41       2.24
# 2     40.69    68.17       6.38
# 3    -42.08    79.32      11.79
# 4    -35.74     75.2       5.82
# 5    -68.31     44.6        4.7
# 6    -52.73       46       8.05
# 7    106.27    57.91        8.1
# 9    -73.83       50       3.36
# 10    150.8    84.19       6.98
# 11  -135.01     46.4        4.7
# 12   147.33    55.99       5.82
# 13   168.86       43       5.99
# 14   108.75    51.42       3.58
# 15   -98.01    59.35       8.01
# 16    14.25    71.01       1.12
# 17   148.25     78.8      14.99
# 18   149.07    75.01       12.3
# 19    12.69    50.52        1.7
# 20    147.9    30.19       6.93
# 21    170.5       46         23
# 22    138.6    59.71      10.58
# 23   -58.16     84.2      11.41
# 24    72.89    79.87       7.83
# 27    -6.59     51.8      18.34
# 28   121.89     62.6      13.87
# 29    103.8    51.79       2.48
# 30    18.42       61       9.17
# 33    19.09    71.05       2.71
# 34   -73.75       63       3.36
# ..      ...      ...        ...
# 588   19.04    51.01       1.12
# 589   73.82    31.99       5.66
# 591  102.26    43.69       0.34
# 592   81.23    73.21       2.28
# 593 -107.96     75.2        4.7
# 594   76.13    46.39       5.73
# 595  -78.15    61.87      13.67
# 596    21.7       68       3.36
# 597   46.76    34.51       6.35
# 598  -76.88    73.02        1.7
# 599   85.18    69.42       9.24
# 600   -7.17     51.8      18.34
# 601  126.17    81.31       3.09
# 602  133.39    34.15       1.36
# 603  -71.64       68      12.75
# 604  108.27    80.95       5.84
# 605   -24.5    80.41      13.35
# 607   -4.19       86       6.93
# 608   47.32    61.69       2.01
# 609   14.43    80.41        7.4
# 610   93.04    36.12       4.81
# 611   88.13    51.25       1.57
# 613  -35.21     78.8       9.17
# 614    -8.8       70       1.01
# 615   60.13    35.05      17.31
# 616  145.57     64.4      10.29
# 617    81.5    35.41       11.7
# 618  149.63    25.15       9.33
# 619 -116.05    102.2      13.87
# 620   82.73    49.62       2.53
#
# [550 rows x 9 columns]

# %%
weather.dtypes
weather.convert_objects(convert_numeric=True).dtypes
# Out:
# C:\Users\atulu\Anaconda1\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# City           object
# Cloudiness      int64
# Country        object
# Date            int64
# Humidity        int64
# Lat           float64
# Lon           float64
# Max Temp      float64
# Wind Speed    float64
# dtype: object

# %%
# converting Raw Data to DataFrame

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Out:
# City          535
# Cloudiness    535
# Country       535
# Date          535
# Humidity      535
# Lat           535
# Lng           535
# Max Temp      535
# Wind Speed    535
# dtype: int64

# %%
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  severo-kurilsk          92      RU  1534988024        93  50.68  156.12
# 1          darhan           8      MN  1534988024        71  49.49  105.92
# 2         tarakan          48      ID  1534988024       100   3.30  117.63
# 3    komsomolskiy          48      RU  1534987754        72  67.55   63.78
# 4        souillac           0      FR  1534986000        73  45.60   -0.60
#
#    Max Temp  Wind Speed
# 0     54.27        2.73
# 1     72.81        8.55
# 2     80.10        4.41
# 3     54.46       15.46
# 4     71.60        3.36

# %% [markdown]
# Latitude vs temperature : As predicted, Temperature is warmer near equator. As latitude is farther from equator temperature is                            going down making it colder.

# %%
plt.scatter(weather["Lat"], weather["Max Temp"],edgecolors="black", c="blue")
plt.title("City Latitude vs. Max Temperature (09/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.grid (linestyle="-")
plt.savefig("City Latitude vs. Max Temperature.png")
plt.show()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# latitude vs Humidity : Poor relationship seems to exist between latitude and humidity. It seems like humidity tends to increase                         with latitude.

# %%
plt.scatter(weather["Lat"], weather["Humidity"],edgecolors="black", c="blue")
plt.title("City Latitude vs. Humidity(09/24/2019)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid (linestyle="-")
plt.savefig("City Latitude vs. Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# Latitude vs cloudiness: It does not seem to have strong realtionship between Latitude and cloudiness.

# %%
plt.scatter(weather["Lat"], weather["Cloudiness"],edgecolors="black", c="blue")
plt.title("City Latitude vs. Cloudiness (09/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid (linestyle="-")
plt.savefig("City Latitude vs. Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# Latitude vs Wind speed : Poor realtionship exist between Latitude and wind speed. However, wind speed seems to stay lower than                         15mph regardless of latitude.

# %%
plt.scatter(weather["Lat"], weather["Wind Speed"],edgecolors="black", c="blue")
plt.title("City Latitude vs. Wind Speed (09/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid (linestyle="-")
plt.savefig("City Latitude vs. Wind Speed.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.322483077139538
